# %% [markdown]
# # Electron Density Temporal Prediction — GAT (Feature Graph + Physics Constraints)
#
# **Task**: Given electron density at 10,540 grid points for **5 consecutive timesteps**, predict density at the **next timestep**.
# **Dataset**: Ammonia NH3 — 401 timesteps (0->2000, step=5).
# **This notebook improves**:
# - Loss weighting includes static nodes with low weight (not zero)
# - Graph uses **feature-similarity edges** + **spatial kNN edges** (no sequential edges)
# - Adds **electron conservation** regularization in training

# %%
import os, glob, json, time, warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspex  
import seaborn as sns
from scipy import stats

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.data import Data, Dataset
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GATConv

warnings.filterwarnings('ignore')
sns.set_style('darkgrid')
plt.rcParams.update({'figure.figsize': (12, 6), 'font.size': 12,
                     'axes.titlesize': 13, 'axes.labelsize': 11})

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"🖥️  Device: {device}")
if torch.cuda.is_available():
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    print(f"   VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
print(f"📦 PyTorch: {torch.__version__}")

SEED = 42
torch.manual_seed(SEED); np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
# Out:
# 🖥️  Device: cuda
#    GPU: NVIDIA RTX A6000
#    VRAM: 50.9 GB
# 📦 PyTorch: 2.2.1+cu121

# %% [markdown]
# ## 2. Configuration

# %%
DATASET_NAME  = "ammonia_x"          
DATA_DIR      = Path("../data/raw") / DATASET_NAME
LOOKBACK      = 5                    
LOOKAHEAD     = 1                    

# Model
HIDDEN_DIM      = 128
NUM_LAYERS      = 4
NUM_HEADS       = 4
DROPOUT         = 0.10
K_NEIGHBORS     = 10   # spatial kNN edges
FEAT_NEIGHBORS  = 8    # feature-similarity edges (cosine kNN)
FEATURE_TOPK_TS = 240  # timesteps from training window used to build node features

# Training
EPOCHS          = 100
LR              = 3e-4
WEIGHT_DECAY    = 1e-4
BATCH_SIZE      = 2
PATIENCE        = 20   
GRAD_CLIP       = 1.0

ACTIVE_STD_THRESHOLD = 1e-6
STATIC_WEIGHT_FLOOR  = 0.12  # static nodes still contribute, but less
LAMBDA_MASS         = 0.20   # electron conservation loss weight
LAMBDA_SMOOTH       = 0.02   # graph smoothness regularizer

TRAIN_RATIO          = 0.80
VAL_RATIO            = 0.10
TEST_RATIO           = 0.10

MODEL_DIR   = Path("../models");  MODEL_DIR.mkdir(exist_ok=True)
REPORTS_DIR = Path("../reports"); REPORTS_DIR.mkdir(exist_ok=True)

print(f"⚙️  Config: dataset={DATASET_NAME}, lookback={LOOKBACK}, lookahead={LOOKAHEAD}")
print(f"   Model: hidden={HIDDEN_DIM}, layers={NUM_LAYERS}, heads={NUM_HEADS}")
print(f"   Graph: spatial_k={K_NEIGHBORS}, feature_k={FEAT_NEIGHBORS}")
print(f"   Training: epochs={EPOCHS}, LR={LR}, batch={BATCH_SIZE}")
print(f"   Weights: active_std_thr={ACTIVE_STD_THRESHOLD}, static_floor={STATIC_WEIGHT_FLOOR}")
print(f"   Physics: lambda_mass={LAMBDA_MASS}, lambda_smooth={LAMBDA_SMOOTH}")
# Out:
# ⚙️  Config: dataset=ammonia_x, lookback=5, lookahead=1
#    Model: hidden=128, layers=4, heads=4
#    Graph: spatial_k=10, feature_k=8
#    Training: epochs=100, LR=0.0003, batch=2
#    Weights: active_std_thr=1e-06, static_floor=0.12
#    Physics: lambda_mass=0.2, lambda_smooth=0.02

# %% [markdown]
# ## 3. Data Loading
#
# Each `rvlab.tdscf.rho.XXXXX` file: 10,540 rows × 2 columns (index | density).
# We load **all 401 timesteps** at once into a matrix for efficient processing.
# **float64** precision is used throughout preprocessing to avoid numerical issues with tiny deltas.

# %%
def load_density_file(fp):
    return np.loadtxt(fp)[:, 1]   

def load_grid_coords(data_dir):
    coords = []
    reading = False
    with open(data_dir / "rvlab.tdscf.xyz") as f:
        for line in f:
            if '[Grid]' in line:
                reading = True; continue
            if reading:
                p = line.strip().split()
                if len(p) == 4:
                    try: coords.append([float(p[1]), float(p[2]), float(p[3])])
                    except ValueError: pass
    return np.array(coords)

density_files = sorted(
    [f for f in glob.glob(str(DATA_DIR / "rvlab.tdscf.rho.*"))
     if not f.endswith('.xyz') and not f.endswith('.out')],
    key=lambda x: int(x.split('.')[-1])
)
timestep_ids = [int(f.split('.')[-1]) for f in density_files]

print(f"📂 {DATASET_NAME}: {len(density_files)} files, t={timestep_ids[0]}→{timestep_ids[-1]}")
print("⏳ Loading all timesteps into float64 matrix...")

all_raw = np.stack([load_density_file(f) for f in density_files], axis=0)  # (T, N)
all_raw = all_raw.astype(np.float64)

grid_coords = load_grid_coords(DATA_DIR)
NUM_NODES   = all_raw.shape[1]
NUM_TS      = all_raw.shape[0]

print(f"   Shape: {all_raw.shape}  —  {NUM_TS} timesteps × {NUM_NODES} nodes")
print(f"   Raw density range: [{all_raw.min():.4e}, {all_raw.max():.4f}]")

all_tf = np.log1p(np.clip(all_raw, 0, None))   # (T, N) float64
print(f"   log1p range:  [{all_tf.min():.4f}, {all_tf.max():.4f}]  (compressed ✅)")

# Electron-count diagnostic (should be nearly conserved across timesteps)
total_electrons = all_raw.sum(axis=1)
te_mean = total_electrons.mean()
te_rel_std_pct = (total_electrons.std() / (te_mean + 1e-20)) * 100
te_span_pct = ((total_electrons.max() - total_electrons.min()) / (te_mean + 1e-20)) * 100

print("\n⚛️ Electron Count Check (sum over grid per timestep):")
print(f"   Mean total electrons: {te_mean:.6e}")
print(f"   Relative std:         {te_rel_std_pct:.4e}%")
print(f"   Peak-to-peak span:    {te_span_pct:.4e}%")
# Out:
# 📂 ammonia_x: 401 files, t=0→2000
# ⏳ Loading all timesteps into float64 matrix...
#    Shape: (401, 10540)  —  401 timesteps × 10540 nodes
#    Raw density range: [7.4166e-17, 196.6391]
#    log1p range:  [0.0000, 5.2864]  (compressed ✅)
#
# ⚛️ Electron Count Check (sum over grid per timestep):
#    Mean total electrons: 1.060970e+05
#    Relative std:         1.9515e-06%
#    Peak-to-peak span:    1.2067e-05%

# %% [markdown]
# ## 4. Dataset Insights & Skewness Analysis
#
# Understanding the two core challenges:
# 1. **Spatial skewness** — density spans 17 orders of magnitude
# 2. **Temporal signal** — consecutive changes are ~0.001% of full range
#
# We compute delta statistics from the **training portion only** (no data leakage).

# %%
n_samples_total = NUM_TS - LOOKBACK - LOOKAHEAD + 1  # = 396
n_train_samples = int(TRAIN_RATIO * n_samples_total)
train_ts_end = n_train_samples + LOOKBACK          # exclusive

all_deltas = np.diff(all_tf, axis=0)
train_deltas = all_deltas[:train_ts_end - 1]

DELTA_MEAN = train_deltas.mean()
DELTA_STD  = train_deltas.std()
SCALE      = 1.0 / (DELTA_STD + 1e-20)

per_node_std  = train_deltas.std(axis=0)
per_node_mean = train_deltas.mean(axis=0)

active_mask = per_node_std > ACTIVE_STD_THRESHOLD
N_ACTIVE    = int(active_mask.sum())
N_STATIC    = int((~active_mask).sum())

# Soft activity weights: static nodes keep low-but-nonzero contribution
std_norm = per_node_std / (per_node_std.mean() + 1e-20)
node_weights_np = np.sqrt(std_norm + 1e-12).astype(np.float32)
node_weights_np = np.clip(node_weights_np, STATIC_WEIGHT_FLOOR, None)
node_weights_np /= node_weights_np.mean()

print("=" * 70)
print("📊 DATA INSIGHTS")
print("=" * 70)
print(f"\n🔹 Raw Density:")
print(f"   Min:    {all_raw.min():.4e}   Max:  {all_raw.max():.4f}")
print(f"   Skew:   {stats.skew(all_raw[0]):.2f}  (highly right-skewed)")
print(f"\n🔹 log1p-Transformed:")
print(f"   Range:  [{all_tf.min():.4f}, {all_tf.max():.4f}]  (compressed ✅)")
print(f"   Skew:   {stats.skew(all_tf[0]):.2f}  (much better)")
print(f"\n🔹 Consecutive Deltas (transformed, training portion):")
print(f"   Range:  [{train_deltas.min():.6e}, {train_deltas.max():.6e}]")
print(f"   Mean:   {DELTA_MEAN:.6e}")
print(f"   Std:    {DELTA_STD:.6e}")
print(f"\n🔹 After Standardization (÷ σ):")
print(f"   Scale factor: {SCALE:.0f}×")
scaled_demo = (train_deltas - DELTA_MEAN) / (DELTA_STD + 1e-20)
print(f"   Range: [{scaled_demo.min():.2f}, {scaled_demo.max():.2f}]  ✅ learnable range!")
print(f"   Std:   {scaled_demo.std():.4f}")
print(f"\n🔹 Node Activity (training deltas):")
print(f"   Active nodes (std > {ACTIVE_STD_THRESHOLD}): {N_ACTIVE} ({N_ACTIVE/NUM_NODES*100:.1f}%)")
print(f"   Static nodes:                         {N_STATIC} ({N_STATIC/NUM_NODES*100:.1f}%)")
print(f"   Weight range (all nodes): [{node_weights_np.min():.4f}, {node_weights_np.max():.4f}]")
print(f"   Static node weight floor: {STATIC_WEIGHT_FLOOR}")

d32 = train_deltas.astype(np.float32).astype(np.float64)
prec_loss = np.abs(train_deltas - d32)
print(f"\n🔹 Precision (float32 vs float64 for delta computation):")
print(f"   Mean precision loss:  {prec_loss.mean():.2e}")
print(f"   As fraction of delta: {prec_loss.mean()/np.abs(train_deltas).mean():.6f} → negligible")
# Out:
# ======================================================================
# 📊 DATA INSIGHTS
# ======================================================================
#
# 🔹 Raw Density:
#    Min:    7.4166e-17   Max:  196.6391
#    Skew:   4.08  (highly right-skewed)
#
# 🔹 log1p-Transformed:
#    Range:  [0.0000, 5.2864]  (compressed ✅)
#    Skew:   3.34  (much better)
#
# 🔹 Consecutive Deltas (transformed, training portion):
#    Range:  [-4.738170e-04, 4.745007e-04]
#    Mean:   -5.692293e-11
#    Std:    6.339347e-05
#
# 🔹 After Standardization (÷ σ):
#    Scale factor: 15774×
#    Range: [-7.47, 7.49]  ✅ learnable range!
#    Std:   1.0000
#
# 🔹 Node Activity (training deltas):
#    Active nodes (std > 1e-06): 6411 (60.8%)
#    Static nodes:                         4129 (39.2%)
#    Weight range (all nodes): [0.1622, 3.3955]
#    Static node weight floor: 0.12
#
# 🔹 Precision (float32 vs float64 for delta computation):
#    Mean precision loss:  6.59e-13
#    As fraction of delta: 0.000000 → negligible

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle(f'Data Analysis: {DATASET_NAME} — Skewness & Delta Signal', fontsize=15, fontweight='bold')

ax = axes[0, 0]
vals = all_raw[0]
ax.hist(np.log10(np.clip(vals, 1e-20, None)), bins=60, color='coral', edgecolor='white', alpha=0.8)
ax.set_xlabel('log₁₀(raw density)'); ax.set_ylabel('Count')
ax.set_title(f'Raw Density Distribution\nskewness={stats.skew(vals):.1f} — extremely right-skewed')

ax = axes[0, 1]
vals_tf = all_tf[0]
ax.hist(vals_tf, bins=60, color='steelblue', edgecolor='white', alpha=0.8)
ax.set_xlabel('log1p(density)'); ax.set_ylabel('Count')
ax.set_title(f'After log1p Transform\nskewness={stats.skew(vals_tf):.2f} — much better')

ax = axes[0, 2]
ax.hist(train_deltas.flatten(), bins=100, color='mediumpurple', edgecolor='white', alpha=0.8, log=True)
ax.set_xlabel('Δρ (raw, transformed space)'); ax.set_ylabel('Count (log)')
ax.set_title(f'Raw Delta Distribution\nσ={DELTA_STD:.2e} — too small for learning!')

ax = axes[1, 0]
ax.hist(scaled_demo.flatten(), bins=100, color='teal', edgecolor='white', alpha=0.8, log=True)
ax.set_xlabel('Δρ / σ (standardized)'); ax.set_ylabel('Count (log)')
ax.set_title(f'Standardized Delta Distribution\nRange: [{scaled_demo.min():.1f}, {scaled_demo.max():.1f}] ✅')

ax = axes[1, 1]
log_std = np.log10(np.clip(per_node_std, 1e-25, None))
ax.hist(log_std, bins=60, color='goldenrod', edgecolor='white', alpha=0.8)
ax.axvline(np.log10(ACTIVE_STD_THRESHOLD), color='red', linestyle='--', lw=2,
           label=f'Threshold: {ACTIVE_STD_THRESHOLD:.0e}')
ax.set_xlabel('log₁₀(per-node delta std)'); ax.set_ylabel('Count')
ax.set_title(f'Node Activity: {N_ACTIVE} active, {N_STATIC} static')
ax.legend()

ax = axes[1, 2]
ax.hist(np.log10(np.clip(all_raw[0, active_mask], 1e-20, None)), bins=40, alpha=0.7,
        color='steelblue', label=f'Active ({N_ACTIVE})', edgecolor='white')
ax.hist(np.log10(np.clip(all_raw[0, ~active_mask], 1e-20, None)), bins=40, alpha=0.7,
        color='lightcoral', label=f'Static ({N_STATIC})', edgecolor='white')
ax.set_xlabel('log₁₀(density)'); ax.set_ylabel('Count')
ax.set_title('Active vs Static Nodes\n(physically active vs quiet regions)')
ax.legend()

plt.tight_layout()
plt.savefig(str(REPORTS_DIR / 'dataset_insights.png'), dpi=150, bbox_inches='tight')
plt.show()
print("💾 Saved: reports/dataset_insights.png")
# Out:
# 💾 Saved: reports/dataset_insights.png

# %% [markdown]
# ## 5. Graph Construction
#
# Two complementary edge types:
# - **Feature-similarity edges** (top-k): connect nodes with similar temporal signatures
# - **kNN spatial edges** (k=10): connect nearest neighbors in 3D space — captures physical locality
#
# This replaces sequential index edges with data-driven relational edges.

# %%
def build_knn_edges(coords, k):
    from sklearn.neighbors import NearestNeighbors
    nbrs = NearestNeighbors(n_neighbors=k+1, algorithm='ball_tree').fit(coords)
    _, idx = nbrs.kneighbors(coords)
    src, dst = [], []
    for i in range(len(coords)):
        for j in idx[i, 1:]:
            src.extend([i, int(j)]); dst.extend([int(j), i])
    return torch.unique(torch.tensor([src, dst], dtype=torch.long), dim=1)

def build_feature_edges(density_tf, train_end_ts, k, max_ts=240):
    from sklearn.neighbors import NearestNeighbors

    # Build per-node temporal signatures from training timesteps only (no leakage).
    ts = density_tf[:train_end_ts]
    if ts.shape[0] > max_ts:
        ts = ts[:max_ts]

    node_feat = ts.T  # (N, T_used)
    mu = node_feat.mean(axis=1, keepdims=True)
    sd = node_feat.std(axis=1, keepdims=True)
    node_feat = (node_feat - mu) / (sd + 1e-8)

    nbrs = NearestNeighbors(n_neighbors=k+1, metric='cosine', algorithm='brute').fit(node_feat)
    _, idx = nbrs.kneighbors(node_feat)

    src, dst = [], []
    for i in range(len(node_feat)):
        for j in idx[i, 1:]:
            src.extend([i, int(j)]); dst.extend([int(j), i])

    return torch.unique(torch.tensor([src, dst], dtype=torch.long), dim=1)

print(f"🔗 Building graph ({NUM_NODES} nodes)...")
feat_edges = build_feature_edges(all_tf, train_ts_end, FEAT_NEIGHBORS, FEATURE_TOPK_TS)
knn_edges  = build_knn_edges(grid_coords, K_NEIGHBORS)
graph_edges = torch.unique(torch.cat([feat_edges, knn_edges], dim=1), dim=1)

print(f"   Feature edges: {feat_edges.shape[1]}")
print(f"   Spatial edges: {knn_edges.shape[1]}")
print(f"   Combined:      {graph_edges.shape[1]}  (avg degree: {graph_edges.shape[1]/NUM_NODES:.1f})")
# Out:
# 🔗 Building graph (10540 nodes)...
#    Feature edges: 108240
#    Spatial edges: 136080
#    Combined:      184018  (avg degree: 17.5)

# %% [markdown]
# ## 6. Dataset — Standardized Delta Prediction
#
# ### Core fix: Delta Standardization
# The model predicts **standardized deltas**: `z = (Δρ - μ) / σ`
# - μ and σ are computed from training data only
# - Scaling keeps target magnitude numerically learnable
# - At inference: `Δρ = z_predicted × σ + μ`
#
# ### Soft Node Weights (Active + Static)
# All nodes are included in the loss.
# - Dynamic nodes get larger weights proportional to temporal variation
# - Static nodes keep a low floor weight (`STATIC_WEIGHT_FLOOR`) so they still influence training
#
# ### Physics Metadata
# Each sample stores target total electrons so training can penalize mass mismatch.

# %%
NODE_WEIGHTS_TENSOR = torch.tensor(node_weights_np, dtype=torch.float32)
ACTIVE_MASK_TENSOR  = torch.tensor(active_mask.astype(np.float32), dtype=torch.float32)

class DensityDataset(Dataset):
    """
    Sliding window: LOOKBACK timesteps -> standardized delta for t+LOOKAHEAD.

    Includes metadata needed by physics-aware training:
    - per-node soft weights (static nodes not removed)
    - target total electrons in original density space
    """
    def __init__(self, density_tf, density_raw, edge_index, node_weights, active_mask_tensor,
                 lookback, lookahead, delta_mean, delta_std):
        super().__init__()
        self.tf    = density_tf      # (T, N) float64
        self.raw   = density_raw     # (T, N) float64
        self.edges = edge_index
        self.w     = node_weights    # (N,) float32
        self.active= active_mask_tensor
        self.lb    = lookback
        self.la    = lookahead
        self.mu    = delta_mean      # float64
        self.sigma = delta_std       # float64
        self.n     = len(density_tf) - lookback - lookahead + 1

    def len(self): return self.n

    def get(self, idx):
        x = torch.tensor(self.tf[idx : idx+self.lb].T, dtype=torch.float32)

        last_i   = idx + self.lb - 1
        target_i = idx + self.lb + self.la - 1

        raw_delta = (self.tf[target_i] - self.tf[last_i])
        std_delta = (raw_delta - self.mu) / (self.sigma + 1e-20)

        target_total = float(self.raw[target_i].sum())

        return Data(
            x             = x,
            edge_index    = self.edges,
            y             = torch.tensor(std_delta.astype(np.float32)),
            node_weights  = self.w,
            active_mask   = self.active,
            last_input    = torch.tensor(self.tf[last_i], dtype=torch.float32),
            abs_target    = torch.tensor(self.tf[target_i], dtype=torch.float32),
            raw_delta     = torch.tensor(raw_delta.astype(np.float32)),
            target_total  = torch.tensor(target_total, dtype=torch.float32),
            ts_idx        = torch.tensor(idx),
        )

dataset = DensityDataset(
    all_tf, all_raw, graph_edges, NODE_WEIGHTS_TENSOR, ACTIVE_MASK_TENSOR,
    LOOKBACK, LOOKAHEAD, DELTA_MEAN, DELTA_STD
)

sample = dataset[0]
print(f"📦 Dataset: {len(dataset)} samples")
print(f"   x shape :      {sample.x.shape}   (nodes × lookback)")
print(f"   y (scaled Δ):  [{sample.y.min():.2f}, {sample.y.max():.2f}]  ✅ learnable range")
print(f"   Expected σ=1:  {sample.y.std():.3f}")
print(f"   target_total:  {sample.target_total.item():.6e}")
# Out:
# 📦 Dataset: 396 samples
#    x shape :      torch.Size([10540, 5])   (nodes × lookback)
#    y (scaled Δ):  [-4.12, 4.12]  ✅ learnable range
#    Expected σ=1:  0.880
#    target_total:  1.060970e+05

# %%
n   = len(dataset)
n_tr= int(TRAIN_RATIO * n)
n_va= int(VAL_RATIO   * n)
n_te= n - n_tr - n_va

train_ds = [dataset[i] for i in range(n_tr)]
val_ds   = [dataset[i] for i in range(n_tr, n_tr+n_va)]
test_ds  = [dataset[i] for i in range(n_tr+n_va, n)]

nw  = min(4, os.cpu_count() or 1)
pin = torch.cuda.is_available()
kw  = dict(num_workers=nw, pin_memory=pin, persistent_workers=nw>0)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  **kw)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, **kw)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, **kw)

print(f"📊 Split  (chronological — NO shuffle):")
print(f"   Train {TRAIN_RATIO:.0%}: {n_tr} samples")
print(f"   Val   {VAL_RATIO:.0%}:  {n_va} samples")
print(f"   Test  {TEST_RATIO:.0%}:  {n_te} samples")
# Out:
# 📊 Split  (chronological — NO shuffle):
#    Train 80%: 316 samples
#    Val   10%:  39 samples
#    Test  10%:  41 samples

# %% [markdown]
# ## 7. Model: Temporal Graph Attention Network
#
# **Architecture flow:**
# ```
# Input (N, 5) → InputProjection(5→128) → 4× [GATConv + LayerNorm + GELU + Residual] → OutputHead(128→1)
# ```
# Model outputs **standardized delta** per node. Post-hoc we un-scale to get the real density change.

# %%
class TemporalGAT(nn.Module):
    """
    4-layer GAT predicting standardized deltas.
    Input dim = LOOKBACK (temporal history at each node).
    Output = 1 scalar per node  (z-scored Δρ).
    """
    def __init__(self, input_dim, hidden=128, n_layers=4, heads=4, dropout=0.10):
        super().__init__()
        self.drop = dropout

        self.proj = nn.Sequential(
            nn.Linear(input_dim, hidden),
            nn.LayerNorm(hidden),
            nn.GELU(),
            nn.Dropout(dropout),
        )

        self.gats  = nn.ModuleList()
        self.norms = nn.ModuleList()
        for i in range(n_layers):
            last   = (i == n_layers - 1)
            out_ch = hidden // heads if not last else hidden
            self.gats.append(GATConv(hidden, out_ch,
                                     heads=heads if not last else 1,
                                     concat=not last,
                                     dropout=dropout, add_self_loops=True))
            self.norms.append(nn.LayerNorm(hidden))

        self.head = nn.Sequential(
            nn.Linear(hidden, hidden // 2), nn.GELU(), nn.Dropout(dropout),
            nn.Linear(hidden // 2, hidden // 4), nn.GELU(),
            nn.Linear(hidden // 4, 1),
        )

    def forward(self, data, return_attn=False):
        x, ei = data.x, data.edge_index
        x = self.proj(x)
        last_a = None
        for gat, norm in zip(self.gats, self.norms):
            xr = x
            if return_attn:
                x, last_a = gat(x, ei, return_attention_weights=True)
            else:
                x = gat(x, ei)
            x = norm(x)
            x = F.gelu(x)
            x = F.dropout(x, p=self.drop, training=self.training)
            if x.shape == xr.shape:
                x = x + xr
        out = self.head(x).squeeze(-1)
        return (out, last_a) if return_attn else out

model = TemporalGAT(LOOKBACK, HIDDEN_DIM, NUM_LAYERS, NUM_HEADS, DROPOUT).to(device)
n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"🏗️  TemporalGAT: {n_params:,} parameters")
print(f"   Input: ({NUM_NODES}, {LOOKBACK})  →  Output: ({NUM_NODES},) standardized delta")
# Out:
# 🏗️  TemporalGAT: 79,489 parameters
#    Input: (10540, 5)  →  Output: (10540,) standardized delta

# %% [markdown]
# ## 8. Training — Soft Weights + Physics-Aware Loss
#
# The loss now has three logical parts:
# 1. **Soft-weighted node MSE**: all nodes contribute, but low-variance nodes contribute less
# 2. **Electron conservation penalty**: penalizes mismatch in total predicted electrons
# 3. **Graph smoothness penalty**: discourages unphysical high-frequency node-to-node spikes
#
# Composite objective:
# ```python
# L = L_weighted_mse + lambda_mass * L_mass + lambda_smooth * L_graph_smooth
# ```
#
# Scheduler: Cosine Annealing with Warm Restarts (`T0=20`).

# %%
class PhysicsAwareLoss(nn.Module):
    """
    Composite objective for electron-density forecasting:
      - Soft-weighted MSE in standardized-delta space
      - Electron conservation regularization in original density space
      - Graph smoothness regularization on predicted node deltas
    """
    def __init__(self, delta_mean, delta_std, lambda_mass=0.2, lambda_smooth=0.02):
        super().__init__()
        self.delta_mean = float(delta_mean)
        self.delta_std = float(delta_std)
        self.lambda_mass = float(lambda_mass)
        self.lambda_smooth = float(lambda_smooth)

    def weighted_mse(self, pred, target, weights):
        sq = (pred - target) ** 2
        return (sq * weights).sum() / (weights.sum() + 1e-12)

    def conservation_loss(self, pred_z, last_input, target_total, num_nodes):
        bsz = target_total.numel()
        pred_z = pred_z.view(bsz, num_nodes)
        last_input = last_input.view(bsz, num_nodes)

        pred_delta = pred_z * self.delta_std + self.delta_mean
        pred_next_logtf = last_input + pred_delta
        pred_next_raw = torch.expm1(pred_next_logtf).clamp_min(0.0)
        pred_total = pred_next_raw.sum(dim=1)

        rel_err = (pred_total - target_total) / (target_total.abs() + 1e-12)
        return torch.mean(rel_err ** 2)

    def smoothness_loss(self, pred, edge_index):
        src, dst = edge_index
        return ((pred[src] - pred[dst]) ** 2).mean()

    def forward(self, pred, batch, num_nodes):
        mse = self.weighted_mse(pred, batch.y, batch.node_weights)
        mass = self.conservation_loss(pred, batch.last_input, batch.target_total.view(-1), num_nodes)
        smooth = self.smoothness_loss(pred, batch.edge_index)
        total = mse + self.lambda_mass * mass + self.lambda_smooth * smooth
        parts = {
            'mse': mse.detach(),
            'mass': mass.detach(),
            'smooth': smooth.detach(),
        }
        return total, parts

criterion = PhysicsAwareLoss(
    delta_mean=DELTA_MEAN, delta_std=DELTA_STD,
    lambda_mass=LAMBDA_MASS, lambda_smooth=LAMBDA_SMOOTH
)
optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer, T_0=20, T_mult=2, eta_min=1e-6)

use_amp = torch.cuda.is_available()
amp_scaler = torch.cuda.amp.GradScaler(enabled=use_amp)

def train_epoch(model, loader, opt, criterion, device, scaler, amp, num_nodes):
    model.train()
    total, n = 0.0, 0
    p_mse, p_mass, p_sm = 0.0, 0.0, 0.0
    for batch in loader:
        batch = batch.to(device, non_blocking=True)
        opt.zero_grad(set_to_none=True)
        with torch.cuda.amp.autocast(enabled=amp):
            pred = model(batch)
            loss, parts = criterion(pred, batch, num_nodes)
        scaler.scale(loss).backward()
        scaler.unscale_(opt)
        torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        scaler.step(opt); scaler.update()

        total += loss.item() * batch.num_graphs
        p_mse += float(parts['mse']) * batch.num_graphs
        p_mass += float(parts['mass']) * batch.num_graphs
        p_sm += float(parts['smooth']) * batch.num_graphs
        n += batch.num_graphs
    return total / n, p_mse / n, p_mass / n, p_sm / n

@torch.no_grad()
def eval_epoch(model, loader, criterion, device, amp, num_nodes):
    model.eval()
    total, n = 0.0, 0
    p_mse, p_mass, p_sm = 0.0, 0.0, 0.0
    for batch in loader:
        batch = batch.to(device, non_blocking=True)
        with torch.cuda.amp.autocast(enabled=amp):
            pred = model(batch)
            loss, parts = criterion(pred, batch, num_nodes)
        total += loss.item() * batch.num_graphs
        p_mse += float(parts['mse']) * batch.num_graphs
        p_mass += float(parts['mass']) * batch.num_graphs
        p_sm += float(parts['smooth']) * batch.num_graphs
        n += batch.num_graphs
    return total / n, p_mse / n, p_mass / n, p_sm / n

best_path = str(MODEL_DIR / f"best_gat_{DATASET_NAME}_lb{LOOKBACK}_improved.pt")
train_l, val_l = [], []
best_val = float('inf')
no_imp   = 0

print("🚀 Training TemporalGAT (soft weights + mass conservation + graph smoothness)")
print(f"   Scheduler: CosineAnnealingWarmRestarts (T0=20, T_mult=2)")
print(f"   Loss nodes: all {NUM_NODES} nodes (static floor={STATIC_WEIGHT_FLOOR})")
print(f"   Loss lambdas: mass={LAMBDA_MASS}, smooth={LAMBDA_SMOOTH}")
print("-" * 80)
t0 = time.time()

for ep in range(1, EPOCHS + 1):
    te = time.time()
    tl, tmse, tmass, tsm = train_epoch(
        model, train_loader, optimizer, criterion, device, amp_scaler, use_amp, NUM_NODES
    )
    vl, vmse, vmass, vsm = eval_epoch(
        model, val_loader, criterion, device, use_amp, NUM_NODES
    )
    scheduler.step(ep)
    train_l.append(tl); val_l.append(vl)

    improved = vl < best_val
    if improved:
        best_val = vl; no_imp = 0
        torch.save(model.state_dict(), best_path)
    else:
        no_imp += 1

    lr_now = optimizer.param_groups[0]['lr']
    if ep % 5 == 0 or ep <= 3 or improved:
        mark = "  <- BEST" if improved else ""
        print(
            f"  Ep {ep:3d}/{EPOCHS} | Train: {tl:.5f} (mse={tmse:.5f}, mass={tmass:.2e}, sm={tsm:.5f}) | "
            f"Val: {vl:.5f} (mse={vmse:.5f}, mass={vmass:.2e}, sm={vsm:.5f}) | "
            f"LR: {lr_now:.1e} | {time.time()-te:.1f}s{mark}"
        )

    if no_imp >= PATIENCE:
        print(f"\n⛔ Early stopping at epoch {ep} (no improvement for {PATIENCE} epochs)")
        break

tot = time.time() - t0
print(f"\n✅ Done: {len(train_l)} epochs, {tot:.0f}s ({tot/60:.1f} min)")
print(f"   Best val loss: {best_val:.6f}")
print(f"   Model saved:  {best_path}")
# Out:
# 🚀 Training TemporalGAT (soft weights + mass conservation + graph smoothness)
#    Scheduler: CosineAnnealingWarmRestarts (T0=20, T_mult=2)
#    Loss nodes: all 10540 nodes (static floor=0.12)
#    Loss lambdas: mass=0.2, smooth=0.02
# --------------------------------------------------------------------------------
#   Ep   1/100 | Train: 2.49295 (mse=2.49291, mass=9.27e-12, sm=0.00215) | Val: 2.64668 (mse=2.64668, mass=3.34e-15, sm=0.00000) | LR: 3.0e-04 | 5.3s  <- BEST
#   Ep   2/100 | Train: 2.49043 (mse=2.49042, mass=1.61e-13, sm=0.00038) | Val: 2.64666 (mse=2.64666, mass=3.89e-15, sm=0.00000) | LR: 2.9e-04 | 4.9s  <- BEST
#   Ep   3/100 | Train: 2.49035 (mse=2.49034, mass=4.74e-14, sm=0.00023) | Val: 2.64666 (mse=2.64666, mass=2.58e-13, sm=0.00000) | LR: 2.8e-04 | 4.9s
#   Ep   5/100 | Train: 2.49030 (mse=2.49029, mass=3.41e-14, sm=0.00015) | Val: 2.64666 (mse=2.64666, mass=3.61e-15, sm=0.00000) | LR: 2.6e-04 | 6.4s  <- BEST
#   Ep  10/100 | Train: 2.49026 (mse=2.49026, mass=6.96e-14, sm=0.00009) | Val: 2.64667 (mse=2.64667, mass=7.44e-14, sm=0.00000) | LR: 1.5e-04 | 5.1s
#   Ep  15/100 | Train: 2.49021 (mse=2.49021, mass=1.05e-14, sm=0.00006) | Val: 2.64666 (mse=2.64666, mass=5.28e-15, sm=0.00000) | LR: 4.5e-05 | 5.2s
#   Ep  16/100 | Train: 2.49022 (mse=2.49022, mass=5.61e-15, sm=0.00006) | Val: 2.64666 (mse=2.64666, mass=4.87e-15, sm=0.00000) | LR: 3.0e-05 | 5.1s  <- BEST
#   Ep  20/100 | Train: 2.49019 (mse=2.49019, mass=1.22e-14, sm=0.00004) | Val: 2.64666 (mse=2.64666, mass=7.31e-14, sm=0.00000) | LR: 3.0e-04 | 5.1s
#   Ep  22/100 | Train: 2.49027 (mse=2.49026, mass=6.76e-14, sm=0.00007) | Val: 2.64666 (mse=2.64666, mass=3.61e-15, sm=0.00000) | LR: 3.0e-04 | 5.2s  <- BEST
#   Ep  25/100 | Train: 2.49026 (mse=2.49026, mass=6.36e-14, sm=0.00006) | Val: 2.64667 (mse=2.64667, mass=3.89e-15, sm=0.00000) | LR: 2.9e-04 | 5.2s
#   Ep  29/100 | Train: 2.49021 (mse=2.49020, mass=5.58e-15, sm=0.00002) | Val: 2.64666 (mse=2.64666, mass=3.48e-15, sm=0.00000) | LR: 2.6e-04 | 5.2s  <- BEST
#   Ep  30/100 | Train: 2.49019 (mse=2.49019, mass=1.56e-14, sm=0.00003) | Val: 2.64665 (mse=2.64665, mass=3.48e-15, sm=0.00000) | LR: 2.6e-04 | 6.6s  <- BEST
#   Ep  33/100 | Train: 2.49017 (mse=2.49017, mass=2.99e-14, sm=0.00004) | Val: 2.64664 (mse=2.64664, mass=1.94e-13, sm=0.00000) | LR: 2.3e-04 | 5.2s  <- BEST
#   Ep  35/100 | Train: 2.49021 (mse=2.49021, mass=2.64e-14, sm=0.00003) | Val: 2.64664 (mse=2.64664, mass=3.20e-15, sm=0.00000) | LR: 2.1e-04 | 5.2s
#   Ep  38/100 | Train: 2.49017 (mse=2.49017, mass=1.98e-14, sm=0.00003) | Val: 2.64663 (mse=2.64663, mass=3.48e-15, sm=0.00000) | LR: 1.7e-04 | 5.2s  <- BEST
#   Ep  40/100 | Train: 2.49017 (mse=2.49017, mass=6.20e-14, sm=0.00004) | Val: 2.64663 (mse=2.64663, mass=2.98e-13, sm=0.00000) | LR: 1.5e-04 | 5.2s
#   Ep  41/100 | Train: 2.49019 (mse=2.49019, mass=3.00e-14, sm=0.00005) | Val: 2.64660 (mse=2.64660, mass=3.34e-15, sm=0.00000) | LR: 1.4e-04 | 5.2s  <- BEST
#   Ep  43/100 | Train: 2.49009 (mse=2.49009, mass=4.54e-14, sm=0.00005) | Val: 2.64655 (mse=2.64655, mass=3.48e-15, sm=0.00000) | LR: 1.2e-04 | 5.2s  <- BEST
#   Ep  44/100 | Train: 2.49001 (mse=2.49001, mass=5.92e-14, sm=0.00011) | Val: 2.64637 (mse=2.64637, mass=2.47e-13, sm=0.00000) | LR: 1.0e-04 | 5.2s  <- BEST
#   Ep  45/100 | Train: 2.49018 (mse=2.49018, mass=8.11e-14, sm=0.00008) | Val: 2.64660 (mse=2.64660, mass=2.96e-13, sm=0.00000) | LR: 9.3e-05 | 5.2s
#   Ep  46/100 | Train: 2.48993 (mse=2.48993, mass=5.00e-14, sm=0.00009) | Val: 2.64633 (mse=2.64633, mass=2.26e-13, sm=0.00000) | LR: 8.3e-05 | 5.2s  <- BEST
#   Ep  50/100 | Train: 2.49002 (mse=2.49001, mass=2.77e-14, sm=0.00007) | Val: 2.64635 (mse=2.64635, mass=2.15e-13, sm=0.00000) | LR: 4.5e-05 | 5.2s
#   Ep  53/100 | Train: 2.48997 (mse=2.48997, mass=1.35e-14, sm=0.00008) | Val: 2.64631 (mse=2.64631, mass=2.78e-15, sm=0.00000) | LR: 2.3e-05 | 5.3s  <- BEST
#   Ep  54/100 | Train: 2.49029 (mse=2.49028, mass=1.46e-14, sm=0.00008) | Val: 2.64630 (mse=2.64630, mass=3.48e-15, sm=0.00000) | LR: 1.7e-05 | 5.2s  <- BEST
#   Ep  55/100 | Train: 2.48986 (mse=2.48986, mass=1.13e-14, sm=0.00008) | Val: 2.64626 (mse=2.64626, mass=3.61e-15, sm=0.00000) | LR: 1.2e-05 | 6.5s  <- BEST
#   Ep  56/100 | Train: 2.48964 (mse=2.48964, mass=1.42e-14, sm=0.00010) | Val: 2.64619 (mse=2.64619, mass=3.61e-15, sm=0.00000) | LR: 8.3e-06 | 5.2s  <- BEST
#   Ep  60/100 | Train: 2.48993 (mse=2.48993, mass=1.12e-14, sm=0.00009) | Val: 2.64623 (mse=2.64623, mass=3.61e-15, sm=0.00000) | LR: 3.0e-04 | 5.2s
#   Ep  65/100 | Train: 2.49011 (mse=2.49011, mass=6.95e-13, sm=0.00010) | Val: 2.64645 (mse=2.64645, mass=1.58e-13, sm=0.00000) | LR: 3.0e-04 | 5.2s
#   Ep  67/100 | Train: 2.48997 (mse=2.48997, mass=1.47e-13, sm=0.00011) | Val: 2.64619 (mse=2.64619, mass=6.40e-15, sm=0.00000) | LR: 2.9e-04 | 6.5s  <- BEST
#   Ep  70/100 | Train: 2.49019 (mse=2.49019, mass=1.02e-13, sm=0.00003) | Val: 2.64648 (mse=2.64648, mass=2.08e-13, sm=0.00000) | LR: 2.9e-04 | 5.2s
#   Ep  71/100 | Train: 2.48990 (mse=2.48990, mass=7.11e-14, sm=0.00013) | Val: 2.64597 (mse=2.64597, mass=2.54e-14, sm=0.00000) | LR: 2.9e-04 | 5.3s  <- BEST
#   Ep  72/100 | Train: 2.48959 (mse=2.48959, mass=4.66e-13, sm=0.00019) | Val: 2.64584 (mse=2.64584, mass=2.07e-13, sm=0.00000) | LR: 2.8e-04 | 5.2s  <- BEST
#   Ep  75/100 | Train: 2.49003 (mse=2.49003, mass=5.76e-14, sm=0.00010) | Val: 2.64605 (mse=2.64605, mass=1.45e-14, sm=0.00000) | LR: 2.7e-04 | 5.2s
#   Ep  79/100 | Train: 2.49021 (mse=2.49021, mass=1.17e-13, sm=0.00005) | Val: 2.64580 (mse=2.64580, mass=3.31e-14, sm=0.00000) | LR: 2.6e-04 | 6.6s  <- BEST
#   Ep  80/100 | Train: 2.48970 (mse=2.48970, mass=6.50e-13, sm=0.00014) | Val: 2.64682 (mse=2.64682, mass=2.24e-12, sm=0.00001) | LR: 2.6e-04 | 5.2s
#   Ep  85/100 | Train: 2.49003 (mse=2.49003, mass=6.54e-13, sm=0.00012) | Val: 2.64667 (mse=2.64667, mass=4.03e-15, sm=0.00000) | LR: 2.3e-04 | 6.5s
#   Ep  88/100 | Train: 2.49013 (mse=2.49013, mass=4.58e-13, sm=0.00012) | Val: 2.64554 (mse=2.64554, mass=2.09e-13, sm=0.00000) | LR: 2.2e-04 | 5.2s  <- BEST
#   Ep  90/100 | Train: 2.48955 (mse=2.48955, mass=7.48e-13, sm=0.00020) | Val: 2.64672 (mse=2.64672, mass=2.50e-15, sm=0.00000) | LR: 2.1e-04 | 5.3s
#   Ep  95/100 | Train: 2.48990 (mse=2.48989, mass=4.22e-13, sm=0.00014) | Val: 2.64683 (mse=2.64683, mass=1.09e-12, sm=0.00005) | LR: 1.8e-04 | 5.2s
#   Ep 100/100 | Train: 2.49016 (mse=2.49016, mass=3.42e-13, sm=0.00003) | Val: 2.64670 (mse=2.64670, mass=2.11e-13, sm=0.00000) | LR: 1.5e-04 | 5.3s
#
# ✅ Done: 100 epochs, 541s (9.0 min)
#    Best val loss: 2.645541
#    Model saved:  ../models/best_gat_ammonia_x_lb5_improved.pt

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Training Progress', fontsize=14, fontweight='bold')

ax = axes[0]
ax.plot(train_l, label='Train',      color='steelblue', lw=2)
ax.plot(val_l,   label='Validation', color='coral',     lw=2)
ax.set_xlabel('Epoch'); ax.set_ylabel('Weighted MSE (scaled delta space)')
ax.set_title('Loss Curves'); ax.legend(); ax.set_yscale('log'); ax.grid(alpha=0.3)

ax = axes[1]
ratio = np.array(val_l) / (np.array(train_l) + 1e-20)
ax.plot(ratio, color='mediumpurple', lw=2)
ax.axhline(1.0, color='gray', ls='--', lw=1)
ax.set_xlabel('Epoch'); ax.set_ylabel('Val / Train Loss')
ax.set_title('Overfitting Monitor\n(>1 = overfitting, <1 = underfitting)')
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(str(REPORTS_DIR / 'training_curves.png'), dpi=150, bbox_inches='tight')
plt.show()
print("💾 Saved: reports/training_curves.png")
# Out:
# 💾 Saved: reports/training_curves.png

# %% [markdown]
# ## 9. Evaluation & Metrics (Model-Only)
#
# **Metric Strategy:**
# 1. Load the **best checkpoint** (not final epoch)
# 2. Collect predictions -> un-scale -> reconstruct absolute density
# 3. Report metrics on **all nodes** AND **active nodes only**
#
# This notebook intentionally reports **model-only metrics** with no reference-model comparison.

# %%
best_path = str(MODEL_DIR / f"best_gat_{DATASET_NAME}_lb{LOOKBACK}_improved.pt")

# Define missing environment flags
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
use_amp = torch.cuda.is_available()

print(f"Device: {device} | AMP: {use_amp}")
# Out:
# Device: cuda | AMP: True

# %%
model.load_state_dict(torch.load(best_path, map_location=device))
model.eval()

buf = {'pred_z':[], 'true_z':[], 'raw_delta':[], 'last_in':[], 'abs_tgt':[], 'w':[], 'active':[], 'target_total':[]}
with torch.no_grad():
    for batch in test_loader:
        batch = batch.to(device, non_blocking=True)
        with torch.cuda.amp.autocast(enabled=use_amp):
            pred = model(batch)
        buf['pred_z'].append(pred.cpu().numpy())
        buf['true_z'].append(batch.y.cpu().numpy())
        buf['raw_delta'].append(batch.raw_delta.cpu().numpy())
        buf['last_in'].append(batch.last_input.cpu().numpy())
        buf['abs_tgt'].append(batch.abs_target.cpu().numpy())
        buf['w'].append(batch.node_weights.cpu().numpy())
        buf['active'].append(batch.active_mask.cpu().numpy())
        buf['target_total'].append(batch.target_total.cpu().numpy())

pred_z    = np.concatenate(buf['pred_z'])
true_z    = np.concatenate(buf['true_z'])
raw_true  = np.concatenate(buf['raw_delta'])
last_in   = np.concatenate(buf['last_in'])
abs_tgt   = np.concatenate(buf['abs_tgt'])
w_all     = np.concatenate(buf['w'])
active_test = np.concatenate(buf['active']).astype(bool)
target_total = np.concatenate(buf['target_total']).astype(np.float64)

pred_delta = pred_z.astype(np.float64) * DELTA_STD + DELTA_MEAN

pred_logtf = last_in.astype(np.float64) + pred_delta
true_logtf = abs_tgt.astype(np.float64)

pred_orig  = np.expm1(pred_logtf)
true_orig  = np.expm1(true_logtf)

# Electron conservation on test set
n_test_samples = len(pred_z) // NUM_NODES
pred_total_series = pred_orig.reshape(n_test_samples, NUM_NODES).sum(axis=1)
true_total_series = true_orig.reshape(n_test_samples, NUM_NODES).sum(axis=1)
mass_rel_err_pct = np.abs((pred_total_series - true_total_series) / (true_total_series + 1e-20)) * 100

print(f"📊 Test predictions: {len(pred_z):,} total  |  active: {active_test.sum():,} ({active_test.mean()*100:.1f}%)")
print(f"   pred_z range:      [{pred_z.min():.2f}, {pred_z.max():.2f}]")
print(f"   pred delta range:  [{pred_delta.min():.4e}, {pred_delta.max():.4e}]")
print(f"   true delta range:  [{raw_true.min():.4e}, {raw_true.max():.4e}]")
print(f"   mass rel err mean: {mass_rel_err_pct.mean():.4f}%")
print(f"   mass rel err p95:  {np.percentile(mass_rel_err_pct, 95):.4f}%")
# Out:
# 📊 Test predictions: 432,140 total  |  active: 262,851 (60.8%)
#    pred_z range:      [-0.01, 0.01]
#    pred delta range:  [-9.0352e-07, 7.3897e-07]
#    true delta range:  [-4.4883e-04, 4.4867e-04]
#    mass rel err mean: 0.0001%
#    mass rel err p95:  0.0001%

# %%
def metrics(pred, true, mask=None):
    if mask is not None:
        pred, true = pred[mask], true[mask]
    res = pred - true
    mse  = float(np.mean(res**2))
    rmse = float(np.sqrt(mse))
    mae  = float(np.mean(np.abs(res)))
    r    = float(np.ptp(true))
    nrmse= rmse / r * 100 if r > 0 else 0.0
    ss_r = np.sum(res**2); ss_t = np.sum((true - true.mean())**2)
    r2   = float(1 - ss_r/ss_t) if ss_t > 0 else 0.0
    nz   = np.abs(true) > 1e-10
    mape = float(np.mean(np.abs(res[nz]/true[nz]))*100) if nz.sum() else float('nan')
    n_p  = np.linalg.norm(pred.flatten()); n_t = np.linalg.norm(true.flatten())
    cos  = float(np.dot(pred.flatten(), true.flatten()) / (n_p * n_t + 1e-20))
    pr   = float(stats.pearsonr(pred.flatten(), true.flatten())[0]) if len(pred) > 1 else 0.0
    within = {}
    for t in [0.1, 0.5, 1.0, 5.0]:
        within[t] = float((np.abs(res[nz]/true[nz])*100 < t).mean()*100) if nz.sum() else 0.0
    return dict(MSE=mse, RMSE=rmse, MAE=mae, NRMSE_pct=nrmse,
                R2=r2, MAPE_pct=mape, Cosine_Sim=cos, Pearson_r=pr,
                **{f'Within_{k}pct':v for k,v in within.items()})

mass_metrics = {
    'Mass_RelErr_Mean_pct': float(mass_rel_err_pct.mean()),
    'Mass_RelErr_Median_pct': float(np.median(mass_rel_err_pct)),
    'Mass_RelErr_P95_pct': float(np.percentile(mass_rel_err_pct, 95)),
}

m = {
    'scaled_model':       metrics(pred_z, true_z),
    'delta_all_model':    metrics(pred_delta, raw_true.astype(np.float64)),
    'delta_act_model':    metrics(pred_delta, raw_true.astype(np.float64), mask=active_test),
    'abs_all_model':      metrics(pred_orig, true_orig),
    'abs_act_model':      metrics(pred_orig, true_orig, mask=active_test),
    'mass_model':         mass_metrics,
}

W = 90
print("=" * W)
print("📊 FINAL TEST METRICS (MODEL-ONLY + PHYSICS)")
print("=" * W)

sections = [
    ("A  Scaled-delta space (model output)", 'scaled_model'),
    ("B  Raw delta — ALL nodes",             'delta_all_model'),
    ("C  Raw delta — ACTIVE nodes only ★",   'delta_act_model'),
    ("D  Absolute density — ALL nodes",      'abs_all_model'),
    ("E  Absolute density — ACTIVE nodes ★", 'abs_act_model'),
]
for title, mk in sections:
    print(f"\n{'─'*W}")
    print(f"  {title}")
    print(f"  {'Metric':<22} {'Model':>14}")
    print(f"  {'─'*22} {'─'*14}")
    for key in ['R2','MAE','RMSE','NRMSE_pct','MAPE_pct','Cosine_Sim']:
        if key not in m[mk]:
            continue
        mv = m[mk][key]
        print(f"  {key:<22} {mv:>14.6f}")
    for t in [0.1,0.3,0.5,1.0,5.0]:
        k = f'Within_{t}pct'
        if k in m[mk]:
            mv = m[mk][k]
            print(f"  {k:<22} {mv:>13.2f}%")

print(f"\n{'─'*W}")
print("  F  Electron Conservation")
print(f"  {'─'*W}")
for k, v in m['mass_model'].items():
    print(f"  {k:<30} {v:>12.6f}%")

print(f"\n{'─'*W}")
print("  MODEL-ONLY SUMMARY")
print(f"  {'─'*W}")
for title, mk in sections:
    print(f"  {title[:45]:<45} MAE: {m[mk]['MAE']:.6e}   R²: {m[mk]['R2']:+.6f}")
print(f"  {'MassRelErrMean(%)':<45} {m['mass_model']['Mass_RelErr_Mean_pct']:.6f}")
# Out:
# ==========================================================================================
# 📊 FINAL TEST METRICS (MODEL-ONLY + PHYSICS)
# ==========================================================================================
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   A  Scaled-delta space (model output)
#   Metric                          Model
#   ────────────────────── ──────────────
#   R2                           0.000413
#   MAE                          0.500123
#   RMSE                         1.035457
#   NRMSE_pct                    7.313742
#   MAPE_pct                 46790.670776
#   Cosine_Sim                   0.051648
#   Within_0.1pct                   0.01%
#   Within_0.5pct                   0.02%
#   Within_1.0pct                   0.05%
#   Within_5.0pct                   0.23%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   B  Raw delta — ALL nodes
#   Metric                          Model
#   ────────────────────── ──────────────
#   R2                           0.000413
#   MAE                          0.000032
#   RMSE                         0.000066
#   NRMSE_pct                    7.313742
#   MAPE_pct                  2051.093275
#   Cosine_Sim                   0.051658
#   Within_0.1pct                   0.01%
#   Within_0.5pct                   0.03%
#   Within_1.0pct                   0.06%
#   Within_5.0pct                   0.26%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   C  Raw delta — ACTIVE nodes only ★
#   Metric                          Model
#   ────────────────────── ──────────────
#   R2                           0.000420
#   MAE                          0.000052
#   RMSE                         0.000084
#   NRMSE_pct                    9.377655
#   MAPE_pct                   105.879600
#   Cosine_Sim                   0.067087
#   Within_0.1pct                   0.00%
#   Within_0.5pct                   0.00%
#   Within_1.0pct                   0.01%
#   Within_5.0pct                   0.04%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   D  Absolute density — ALL nodes
#   Metric                          Model
#   ────────────────────── ──────────────
#   R2                           1.000000
#   MAE                          0.000096
#   RMSE                         0.000379
#   NRMSE_pct                    0.000193
#   MAPE_pct                   451.252946
#   Cosine_Sim                   1.000000
#   Within_0.1pct                  73.69%
#   Within_0.5pct                  85.56%
#   Within_1.0pct                  87.11%
#   Within_5.0pct                  90.45%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   E  Absolute density — ACTIVE nodes ★
#   Metric                          Model
#   ────────────────────── ──────────────
#   R2                           1.000000
#   MAE                          0.000151
#   RMSE                         0.000485
#   NRMSE_pct                    0.000248
#   MAPE_pct                     0.045780
#   Cosine_Sim                   1.000000
#   Within_0.1pct                  89.19%
#   Within_0.5pct                 100.00%
#   Within_1.0pct                 100.00%
#   Within_5.0pct                 100.00%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   F  Electron Conservation
#   ──────────────────────────────────────────────────────────────────────────────────────────
#   Mass_RelErr_Mean_pct               0.000060%
#   Mass_RelErr_Median_pct             0.000061%
#   Mass_RelErr_P95_pct                0.000064%
#
# ──────────────────────────────────────────────────────────────────────────────────────────
#   MODEL-ONLY SUMMARY
#   ──────────────────────────────────────────────────────────────────────────────────────────
#   A  Scaled-delta space (model output)          MAE: 5.001231e-01   R²: +0.000413
#   B  Raw delta — ALL nodes                      MAE: 3.170454e-05   R²: +0.000413
#   C  Raw delta — ACTIVE nodes only ★            MAE: 5.195471e-05   R²: +0.000420
#   D  Absolute density — ALL nodes               MAE: 9.626759e-05   R²: +1.000000
#   E  Absolute density — ACTIVE nodes ★          MAE: 1.505816e-04   R²: +1.000000
#   MassRelErrMean(%)                             0.000060

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(20, 18))
gs  = gridspec.GridSpec(3, 3, figure=fig, hspace=0.38, wspace=0.3)
fig.suptitle(f'Test Evaluation — {DATASET_NAME} — Model-Only', fontsize=16, fontweight='bold')

NP = 50_000
ridx = np.random.choice(len(pred_z), min(NP, len(pred_z)), replace=False)

# 1) Scaled delta: pred vs true
ax = fig.add_subplot(gs[0, 0])
ax.scatter(true_z[ridx], pred_z[ridx], alpha=0.03, s=1, c='steelblue')
lim = max(np.abs(true_z[ridx]).max(), np.abs(pred_z[ridx]).max())
ax.plot([-lim,lim],[-lim,lim],'r--',lw=1); ax.set_aspect('equal')
ax.set_xlabel('True Δρ/σ'); ax.set_ylabel('Predicted Δρ/σ')
ax.set_title(f'Scaled Delta: Pred vs True\nR²={m["scaled_model"]["R2"]:.5f}')

# 2) Raw delta active nodes
ax = fig.add_subplot(gs[0, 1])
ai = np.where(active_test)[0]
sai= ai[np.random.choice(len(ai), min(NP,len(ai)), replace=False)]
ax.scatter(raw_true[sai], pred_delta[sai], alpha=0.04, s=1, c='teal')
lim = max(np.abs(raw_true[sai]).max(), np.abs(pred_delta[sai]).max())
ax.plot([-lim,lim],[-lim,lim],'r--',lw=1)
ax.set_xlabel('True Δρ (raw)'); ax.set_ylabel('Pred Δρ (raw)')
ax.set_title(f'Raw Delta — Active Nodes\nR²={m["delta_act_model"]["R2"]:.5f}')

# 3) Absolute density log scale
ax = fig.add_subplot(gs[0, 2])
ax.scatter(np.log10(np.clip(true_orig[ridx],1e-20,None)),
           np.log10(np.clip(pred_orig[ridx],1e-20,None)),
           alpha=0.02, s=1, c='coral')
mn = min(np.log10(np.clip(true_orig,1e-20,None)).min(), np.log10(np.clip(pred_orig,1e-20,None)).min())
mx = max(np.log10(np.clip(true_orig,1e-20,None)).max(), np.log10(np.clip(pred_orig,1e-20,None)).max())
ax.plot([mn,mx],[mn,mx],'r--',lw=1)
ax.set_xlabel('log10(True rho)'); ax.set_ylabel('log10(Pred rho)')
ax.set_title(f'Absolute Density (log)\nNRMSE={m["abs_all_model"]["NRMSE_pct"]:.5f}%')

# 4) Residual distribution (active nodes)
ax = fig.add_subplot(gs[1, 0])
resid_act = (pred_delta - raw_true.astype(np.float64))[active_test]
ax.hist(resid_act, bins=100, color='mediumpurple', edgecolor='white', alpha=0.8, log=True)
ax.axvline(0, color='red', ls='--')
ax.set_xlabel('Delta Residual'); ax.set_ylabel('Count (log)')
ax.set_title(f'Delta Residuals (active nodes)\nBias={resid_act.mean():.2e}  Std={resid_act.std():.2e}')

# 5) Most active node: delta over time
ax = fig.add_subplot(gs[1, 1])
top_node = np.argsort(per_node_std)[-1]
n_test_s = len(test_ds)
pred_node = pred_delta.reshape(n_test_s, NUM_NODES)[:, top_node]
true_node = raw_true.reshape(n_test_s, NUM_NODES)[:, top_node]
ax.plot(true_node, 'b-', lw=2, alpha=0.8, label='True Delta')
ax.plot(pred_node, 'r--', lw=2, alpha=0.8, label='Pred Delta')
ax.axhline(0, color='gray', ls=':', lw=0.5)
ax.set_xlabel('Test sample'); ax.set_ylabel('Delta')
ax.set_title(f'Delta Dynamics — Most Active Node ({top_node})'); ax.legend()

# 6) Per-node absolute error distribution (active nodes, first test sample)
ax = fig.add_subplot(gs[1, 2])
me1 = np.abs(pred_orig[:NUM_NODES] - true_orig[:NUM_NODES])
act1= node_weights_np > 0
ax.scatter(np.log10(np.clip(true_orig[:NUM_NODES][act1],1e-20,None)),
           np.log10(np.clip(me1[act1],1e-25,None)),
           alpha=0.15, s=3, c='steelblue')
ax.set_xlabel('log10(True density)'); ax.set_ylabel('log10(Model abs error)')
ax.set_title('Model Error vs True Density (active nodes)')

# 7) Within-X% (model-only, key spaces)
ax = fig.add_subplot(gs[2, 0])
thresholds = [0.1, 0.5, 1.0, 5.0]
s = [m['scaled_model'].get(f'Within_{t}pct', 0) for t in thresholds]
d = [m['delta_act_model'].get(f'Within_{t}pct', 0) for t in thresholds]
a = [m['abs_act_model'].get(f'Within_{t}pct', 0) for t in thresholds]
xx = np.arange(len(thresholds)); wd = 0.25
ax.bar(xx-wd, s, wd, label='Scaled delta', color='steelblue', alpha=0.8)
ax.bar(xx,    d, wd, label='Raw delta (active)', color='teal', alpha=0.8)
ax.bar(xx+wd, a, wd, label='Abs density (active)', color='coral', alpha=0.8)
ax.set_xticks(xx); ax.set_xticklabels([f'{t}%' for t in thresholds])
ax.set_xlabel('Threshold'); ax.set_ylabel('% nodes within')
ax.set_title('Within-X% Accuracy (model-only)'); ax.legend()

# 8) R² across model metric spaces
ax = fig.add_subplot(gs[2, 1])
cats = ['Scaled Delta', 'Raw Delta\n(all)', 'Raw Delta\n(active)', 'Abs Density\n(all)', 'Abs Density\n(active)']
mr   = [m['scaled_model']['R2'], m['delta_all_model']['R2'],
        m['delta_act_model']['R2'], m['abs_all_model']['R2'], m['abs_act_model']['R2']]
xx = np.arange(len(cats))
ax.bar(xx, mr, width=0.55, color='steelblue', alpha=0.85)
ax.set_xticks(xx); ax.set_xticklabels(cats, fontsize=9)
ax.set_ylabel('R²'); ax.set_title('Model R² by Metric Space')
ax.axhline(0, color='gray', ls='--', lw=0.5)

# 9) Density profile: true vs model
ax = fig.add_subplot(gs[2, 2])
show_n = 300
si = np.linspace(0, NUM_NODES-1, show_n, dtype=int)
ax.plot(si, true_orig[:NUM_NODES][si], 'b-',  lw=1.5, label='True', alpha=0.8)
ax.plot(si, pred_orig[:NUM_NODES][si], 'r--', lw=1.5, label='Model', alpha=0.8)
ax.set_xlabel('Grid point (subset)'); ax.set_ylabel('Density')
ax.set_title('Density Profile — first test sample'); ax.legend()

plt.savefig(str(REPORTS_DIR / 'test_evaluation_no_baseline.png'), dpi=150, bbox_inches='tight')
plt.show()
print("💾 Saved: reports/test_evaluation_no_baseline.png")
# Out:
# 💾 Saved: reports/test_evaluation_no_baseline.png

# %%
model.eval()
sd = test_ds[0].to(device)
with torch.no_grad():
    with torch.cuda.amp.autocast(enabled=use_amp):
        _, (ei_a, aw) = model(sd, return_attn=True)

aw_np = aw.cpu().numpy().flatten()
ei_np = ei_a.cpu().numpy()

# Per-node attention received
attn_recv = np.zeros(NUM_NODES)
attn_cnt  = np.zeros(NUM_NODES)
for e in range(ei_np.shape[1]):
    d = ei_np[1, e]
    if d < NUM_NODES and e < len(aw_np):
        attn_recv[d] += aw_np[e]; attn_cnt[d] += 1
attn_avg = attn_recv / (attn_cnt + 1e-10)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Attention Analysis (last GAT layer)', fontsize=14, fontweight='bold')

ax = axes[0]
ax.hist(aw_np, bins=80, color='steelblue', edgecolor='white', alpha=0.8)
ax.set_xlabel('Attention weight'); ax.set_ylabel('Count')
ax.set_title(f'Attention Distribution\nRange [{aw_np.min():.3f}, {aw_np.max():.3f}]')

ax = axes[1]
ax.plot(attn_avg, alpha=0.5, lw=0.5, color='teal')
ax.set_xlabel('Node index'); ax.set_ylabel('Mean attention received')
ax.set_title('Per-Node Attention\n(which nodes get the most information?)')

ax = axes[2]
valid = attn_cnt > 0
ax.scatter(per_node_std[valid], attn_avg[valid], alpha=0.1, s=3, c='mediumpurple')
ax.set_xscale('log'); ax.set_xlabel('Node temporal std (activity)')
ax.set_ylabel('Mean attention received')
ax.set_title('Attention vs Node Activity\n(are dynamic nodes attended more?)')

plt.tight_layout()
plt.savefig(str(REPORTS_DIR / 'attention_analysis.png'), dpi=150, bbox_inches='tight')
plt.show()
print("💾 Saved: reports/attention_analysis.png")
# Out:
# 💾 Saved: reports/attention_analysis.png

# %% [markdown]
# ## 12. Save Model Weights & Predictions

# %%
final_path = str(MODEL_DIR / f"final_gat_{DATASET_NAME}_lb{LOOKBACK}_improved.pt")
torch.save({
    'model_state_dict': model.state_dict(),
    'config': {
        'version': '3_featureGraph_softWeights_massConservation',
        'dataset': DATASET_NAME,
        'lookback': LOOKBACK,
        'lookahead': LOOKAHEAD,
        'hidden_dim': HIDDEN_DIM,
        'num_layers': NUM_LAYERS,
        'num_heads': NUM_HEADS,
        'dropout': DROPOUT,
        'k_neighbors': K_NEIGHBORS,
        'feature_neighbors': FEAT_NEIGHBORS,
        'feature_topk_ts': FEATURE_TOPK_TS,
        'num_nodes': NUM_NODES,
        'train_epochs': len(train_l),
        'best_val_loss': best_val,
        'delta_mean': float(DELTA_MEAN),
        'delta_std':  float(DELTA_STD),
        'active_threshold': ACTIVE_STD_THRESHOLD,
        'static_weight_floor': STATIC_WEIGHT_FLOOR,
        'lambda_mass': LAMBDA_MASS,
        'lambda_smooth': LAMBDA_SMOOTH,
        'evaluation_mode': 'model_only_with_physics',
    },
    'metrics': m,
    'node_weights': node_weights_np,
}, final_path)
print(f"💾 Final model: {final_path}")
print(f"💾 Best model:  {best_path}")

pred_file = str(REPORTS_DIR / f"test_predictions_{DATASET_NAME}_improved.npz")
np.savez_compressed(
    pred_file,
    pred_density_original = pred_orig.astype(np.float32),
    true_density_original = true_orig.astype(np.float32),
    pred_delta            = pred_delta.astype(np.float32),
    true_delta            = raw_true,
    pred_scaled           = pred_z,
    true_scaled           = true_z,
    active_mask           = active_test,
    node_weights          = node_weights_np,
    pred_total_electrons  = pred_total_series.astype(np.float32),
    true_total_electrons  = true_total_series.astype(np.float32),
    mass_rel_err_pct      = mass_rel_err_pct.astype(np.float32),
)
print(f"💾 Predictions: {pred_file}")

def ser(o):
    if isinstance(o, float) and (np.isnan(o) or np.isinf(o)): return str(o)
    if isinstance(o, (np.floating, float)): return float(o)
    if isinstance(o, dict): return {k: ser(v) for k, v in o.items()}
    return o

mpath = str(REPORTS_DIR / f"metrics_{DATASET_NAME}_improved.json")
with open(mpath, 'w') as f:
    json.dump(ser(m), f, indent=2)
print(f"💾 Metrics: {mpath}")

print("\n✅ All outputs saved to reports/ and models")
# Out:
# 💾 Final model: ../models/final_gat_ammonia_x_lb5_improved.pt
# 💾 Best model:  ../models/best_gat_ammonia_x_lb5_improved.pt
# 💾 Predictions: ../reports/test_predictions_ammonia_x_improved.npz
# 💾 Metrics: ../reports/metrics_ammonia_x_improved.json
#
# ✅ All outputs saved to reports/ and models

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 1. Selection & Thresholding
sample_idx = 19  # First test snapshot
N = NUM_NODES
true_data = true_orig[sample_idx*N : (sample_idx+1)*N]
pred_data = pred_orig[sample_idx*N : (sample_idx+1)*N]

# Filter out the vacuum (only show points with meaningful density)
# Adjust this threshold if the molecule looks too 'thin' or too 'bloated'
threshold = 0.02 
mask_true = true_data > threshold
mask_pred = pred_data > threshold

# 2. Setup the Plot
fig = plt.figure(figsize=(22, 10))
fig.suptitle(f"3D Molecular Pattern Reconstruction Analysis\nSnapshot {sample_idx}", 
             fontsize=20, fontweight='bold', y=0.95)

# Panel 1: True Physical Structure
ax1 = fig.add_subplot(121, projection='3d')
sc1 = ax1.scatter(grid_coords[mask_true, 0], grid_coords[mask_true, 1], grid_coords[mask_true, 2], 
                  c=true_data[mask_true], 
                  cmap='magma',     # High-contrast color map
                  s=12,             # Size of points
                  alpha=0.3,        # Base transparency
                  edgecolors='none')
ax1.set_title("Actual Physical Density Structure", fontsize=15, pad=20)
ax1.set_xlabel('X (Bohr)'); ax1.set_ylabel('Y (Bohr)'); ax1.set_zlabel('Z (Bohr)')

# Panel 2: GNN Predicted Structure
ax2 = fig.add_subplot(122, projection='3d')
sc2 = ax2.scatter(grid_coords[mask_pred, 0], grid_coords[mask_pred, 1], grid_coords[mask_pred, 2], 
                  c=pred_data[mask_pred], 
                  cmap='magma', 
                  s=12, 
                  alpha=0.3, 
                  edgecolors='none')
ax2.set_title("GNN Predicted Density Structure", fontsize=15, pad=20)
ax2.set_xlabel('X (Bohr)'); ax2.set_ylabel('Y (Bohr)'); ax2.set_zlabel('Z (Bohr)')

# 3. Aesthetics & Viewing Angle
for ax in [ax1, ax2]:
    ax.set_facecolor('white')
    # Set a professional viewing angle to see the pyramidal shape of Ammonia
    ax.view_init(elev=25, azim=45) 
    # Remove pane background for a cleaner look
    ax.xaxis.pane.fill = False; ax.yaxis.pane.fill = False; ax.zaxis.pane.fill = False

# Add colorbar
cbar_ax = fig.add_axes([0.93, 0.25, 0.015, 0.5])
fig.colorbar(sc1, cax=cbar_ax, label='Electron Density (ρ)')

plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
# =============================================================================
# 16. SCIENTIFIC 3D ERROR MAP (RESIDUAL ANALYSIS)
# =============================================================================
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 1. Calculate the Error (Residuals)
# We look at the difference: What did we predict vs what was actually there?
error = pred_data - true_data

# Filter for 'Active' nodes only (so we don't plot the empty vacuum)
# threshold = 0.01 (adjust as needed to see the molecule shape)
mask = (true_data > 0.01) | (pred_data > 0.01)

# 2. Setup Plot
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')
fig.suptitle(f"Spatial Error Analysis (Snapshot {sample_idx})\nColor = Prediction Error (Pred - True)", 
             fontsize=16, fontweight='bold')

# 3. Plot the Error Map
# Use 'coolwarm' colormap: 
# Red = Model over-predicted (guessed too high)
# Blue = Model under-predicted (guessed too low)
# White = Model was perfect
limit = np.percentile(np.abs(error[mask]), 95) # Auto-scale color based on 95th percentile error

sc = ax.scatter(grid_coords[mask, 0], grid_coords[mask, 1], grid_coords[mask, 2], 
                c=error[mask], 
                cmap='coolwarm', 
                s=20, 
                vmin=-limit, vmax=limit, # Centers the white color at 0 error
                alpha=0.6,
                edgecolors='none')

# Add a Colorbar explaining the errors
cbar = plt.colorbar(sc, ax=ax, shrink=0.5, pad=0.1)
cbar.set_label('Prediction Error (Residual)', fontsize=12)

# Labels & Aesthetics
ax.set_xlabel('X'); ax.set_ylabel('Y'); ax.set_zlabel('Z')
ax.view_init(elev=25, azim=45)
ax.set_facecolor('white')
ax.xaxis.pane.fill = False; ax.yaxis.pane.fill = False; ax.zaxis.pane.fill = False

plt.show()
